# %%
# %pip install numpy pandas
import numpy as np
import pandas as pd
# Out:
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/12.4 MB 5.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 3.7/12.4 MB 11.7 MB/s eta 0:00:01
#    ------------ --------------------------- 3.9/12.4 MB 11.2 MB/s eta 0:00:01
#    ------------ --------------------------- 3.9/12.4 MB 11.2 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.4 MB 4.8 MB/s eta 0:00:02
#    ------------- -------------------------- 4.2/12.4 MB 4.8 MB/s eta 0:00:02
#    ------------------ --------------------- 5.8/12.4 MB 4.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.2/12.4 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 7.0 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 6.7 MB/s eta 0:00:02
# ...

# %%
data = pd.read_csv('http://127.0.0.1:8000/api/Student/')

# %%
data
# Out:
# Empty DataFrame
# Columns: [[{"id":1, name:"Rahul", age:21, course:"AI"}, {"id":2, name:"BEN", age:21.1, course:"AI"}.1, {"id":4, name:"Amit", age:15, course:"ML"}, {"id":6, name:"anshika", age:18, course:"CA"}, {"id":7, name:"Rakshith", age:20, course:"CLOUD COMPUTING"}, {"id":8, name:"Ranadheer", age:22, course:"ML"}]]
# Index: []
#
# [0 rows x 24 columns]
